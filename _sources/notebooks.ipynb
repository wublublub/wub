# %% [markdown]
# # NBA爬虫数据分析
#
# 本次实训期间我个人完成的一个对于网页爬取功能的实现以及在此基础上对于多文件整合的数据分析
#
# ## 爬取数据展示(部分)

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('../Team_schedules/lakers_schedule.csv')

# 显示数据框
print(df)
# Out:
#                客队vs主队         比分   结果                 比赛时间 数据统计
# 0    2023至2024赛季湖人队赛程        NaN  NaN                  NaN  NaN
# 1        北京时间2023年10月        NaN  NaN                  NaN  NaN
# 2              客队vs主队         比分   结果                 北京时间  NaN
# 3            湖人 vs 勇士  108 - 125    负  2023-10-08 08:30:00
# 4            篮网 vs 湖人  126 - 129    胜  2023-10-10 09:00:00
# ..                ...        ...  ...                  ...  ...
# 108          湖人 vs 掘金          -    -  2024-04-30 01:00:00
# 109      北京时间2024年05月        NaN  NaN                  NaN  NaN
# 110            客队vs主队         比分   结果                 北京时间  NaN
# 111          掘金 vs 湖人          -    -  2024-05-03 01:00:00
# 112          湖人 vs 掘金          -    -  2024-05-05 01:00:00
#
# [113 rows x 5 columns]
